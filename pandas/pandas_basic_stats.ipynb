# %% [markdown]
# <a href="https://colab.research.google.com/github/dlont/hep/blob/main/pandas/pandas_basic_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_train = pd.read_csv('higgs-boson/training/training.csv')

# %%
print("Listing first top 5 rows:")
print(data_train.head())

# %%
print("Listing last bottom 5 rows:")
print(data_train.tail())

# %%
print("Descriptive statistics:")
print(data_train.describe())
